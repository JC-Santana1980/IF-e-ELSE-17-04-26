# %% [markdown]
# <a href="https://colab.research.google.com/github/JC-Santana1980/IF-e-ELSE-17-04-26/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3-Uma loja online permite que seus clientes escolham entre dois tipos de entrega:
#
# "padrão": Custa R$10,00.
#
# "expresso": Custa R$20,00.
#
# Qualquer outra opção deve exibir: "Opção de entrega inválida.".

# %%
print("Entrega Padrao = P")
print("Entrega Expressa = E")
print("Outra opcao = O")

entrega = input ("digite o tipo de entrega: ").upper()
if entrega == "P" :
  print ("Entrega padrao: r$ 10,00")
elif entrega == "E" :
  print ("Entrega expresso r$ 20,00: ")
else:
  print("Opcao de entrega nao disponivel")
# Out:
# Entrega Padrao = P
# Entrega Expressa = E
# Outra opcao = O
# digite o tipo de entrega: w
# Opcao de entrega nao disponivel
