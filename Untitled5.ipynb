# %% [markdown]
# <a href="https://colab.research.google.com/github/JC-Santana1980/IF-e-ELSE-17-04-26/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input(" Digite sua idade : "))
if idade < 16:
  print ("Nao permitido : ")
elif idade >= 16 and idade <= 17 :
  print ("opcional : ")
elif idade >= 18 and idade <=75:
    print ("Obrigatorio : ")
else:
  print ("Opcional : ")
# Out:
#  Digite sua idade : 100
# Opcional :
